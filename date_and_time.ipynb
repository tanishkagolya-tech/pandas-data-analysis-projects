# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Timestamp Object
# Time stamps reference particular moments in time (e.g., Oct 24th, 2022 at 7:00pm)

# %% [markdown]
# Creating Timestamp objects

# %%
pd.Timestamp('2026-06-1')
# Out:
# Timestamp('2026-06-01 00:00:00')

# %%
type(pd.Timestamp('2026-06-1'))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#variations
pd.Timestamp('2026/06/1')
pd.Timestamp('2026,06,1')
# Out:
# Timestamp('2026-01-01 00:00:00')

# %%
# only year
pd.Timestamp('2023')
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
# using text
pd.Timestamp('5th January 2023')
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
# providing time also
pd.Timestamp('5th January 2023 9:21AM')
# pd.Timestamp('2023/1/5/9/21')
# Out:
# Timestamp('2023-01-05 09:21:00')

# %%
# AM and PM
pd.Timestamp('6July 2026 6:14PM')
# Out:
# Timestamp('2026-07-06 18:14:00')

# %%
import datetime as dt
x = pd.Timestamp(dt.datetime(2026,6,1,6,15,56))
x
# Out:
# Timestamp('2026-06-01 06:15:56')

# %%
# fetching attributes
x.year
x.month
x.day
x.hour
x.minute
x.second
# Out:
# 56

# %%
# why separate objects to handle data and time when python already has datetime functionality?

# %% [markdown]
# syntax wise datetime is very convenient
# But the performance takes a hit while working with huge data. List vs Numpy Array
# The weaknesses of Python's datetime format inspired the NumPy team to add a set of native time series data type to NumPy.
# The datetime64 dtype encodes dates as 64-bit integers, and thus allows arrays of dates to be represented very compactly.

# %%
import numpy as np
date = np.array('2026-06-04', dtype=np.datetime64)
date
# Out:
# array('2026-06-04', dtype='datetime64[D]')

# %%
date + np.arange(12)
# Out:
# array(['2026-06-04', '2026-06-05', '2026-06-06', '2026-06-07',
#        '2026-06-08', '2026-06-09', '2026-06-10', '2026-06-11',
#        '2026-06-12', '2026-06-13', '2026-06-14', '2026-06-15'],
#       dtype='datetime64[D]')

# %% [markdown]
# Because of the uniform type in NumPy datetime64 arrays, this type of operation can be accomplished much more quickly than if we were working directly with Python's datetime objects, especially as arrays get large
#
# Pandas Timestamp object combines the ease-of-use of python datetime with the efficient storage and vectorized interface of numpy.datetime64
#
# From a group of these Timestamp objects, Pandas can construct a DatetimeIndex that can be used to index data in a Series or DataFrame

# %% [markdown]
# DatetimeIndex Object
# A collection of pandas timestamp

# %%
# from strings
type(pd.DatetimeIndex(['2023/1/1','2022/1/1','2021/1/1']))
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# from strings
pd.DatetimeIndex(['2023/1/1','2022/1/1','2021/1/1'])
# Out:
# DatetimeIndex(['2023-01-01', '2022-01-01', '2021-01-01'], dtype='datetime64[ns]', freq=None)

# %%
# using python datetime object
pd.DatetimeIndex([dt.datetime(2023,1,1),dt.datetime(2022,1,1),dt.datetime(2021,1,1)])
# Out:
# DatetimeIndex(['2023-01-01', '2022-01-01', '2021-01-01'], dtype='datetime64[ns]', freq=None)

# %%
# using pd.timestamps
dt_index = pd.DatetimeIndex([pd.Timestamp(2023,1,1),pd.Timestamp(2022,1,1),pd.Timestamp(2021,1,1)])

# %%
# using datatimeindex as series index

pd.Series([1,2,3],index=dt_index)
# Out:
# 2023-01-01    1
# 2022-01-01    2
# 2021-01-01    3
# dtype: int64

# %% [markdown]
# ### date_range function

# %%
# generate daily dates in a given range
pd.date_range(start='2026-6-1', end='2026-8-1',freq='3D')
# Out:
# DatetimeIndex(['2026-06-01', '2026-06-04', '2026-06-07', '2026-06-10',
#                '2026-06-13', '2026-06-16', '2026-06-19', '2026-06-22',
#                '2026-06-25', '2026-06-28', '2026-07-01', '2026-07-04',
#                '2026-07-07', '2026-07-10', '2026-07-13', '2026-07-16',
#                '2026-07-19', '2026-07-22', '2026-07-25', '2026-07-28',
#                '2026-07-31'],
#               dtype='datetime64[ns]', freq='3D')

# %%
# alternate days in a given range
pd.date_range(start='2023/1/5',end='2023/2/28',freq='3D')
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-08', '2023-01-11', '2023-01-14',
#                '2023-01-17', '2023-01-20', '2023-01-23', '2023-01-26',
#                '2023-01-29', '2023-02-01', '2023-02-04', '2023-02-07',
#                '2023-02-10', '2023-02-13', '2023-02-16', '2023-02-19',
#                '2023-02-22', '2023-02-25', '2023-02-28'],
#               dtype='datetime64[ns]', freq='3D')

# %%
# B -> business days
pd.date_range(start='2023/1/5',end='2023/2/28',freq='B')
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-06', '2023-01-09', '2023-01-10',
#                '2023-01-11', '2023-01-12', '2023-01-13', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                '2023-01-23', '2023-01-24', '2023-01-25', '2023-01-26',
#                '2023-01-27', '2023-01-30', '2023-01-31', '2023-02-01',
#                '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07',
#                '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13',
#                '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17',
#                '2023-02-20', '2023-02-21', '2023-02-22', '2023-02-23',
#                '2023-02-24', '2023-02-27', '2023-02-28'],
#               dtype='datetime64[ns]', freq='B')

# %%
# W -> one week per day
pd.date_range(start='2023/1/5',end='2023/2/28',freq='W-THU')
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-12', '2023-01-19', '2023-01-26',
#                '2023-02-02', '2023-02-09', '2023-02-16', '2023-02-23'],
#               dtype='datetime64[ns]', freq='W-THU')

# %%
# H -> Hourly data(factor)
pd.date_range(start='2023/1/5',end='2023/2/28',freq='6H')
# Out:
# /tmp/ipykernel_2149/987353597.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start='2023/1/5',end='2023/2/28',freq='6H')
# DatetimeIndex(['2023-01-05 00:00:00', '2023-01-05 06:00:00',
#                '2023-01-05 12:00:00', '2023-01-05 18:00:00',
#                '2023-01-06 00:00:00', '2023-01-06 06:00:00',
#                '2023-01-06 12:00:00', '2023-01-06 18:00:00',
#                '2023-01-07 00:00:00', '2023-01-07 06:00:00',
#                ...
#                '2023-02-25 18:00:00', '2023-02-26 00:00:00',
#                '2023-02-26 06:00:00', '2023-02-26 12:00:00',
#                '2023-02-26 18:00:00', '2023-02-27 00:00:00',
#                '2023-02-27 06:00:00', '2023-02-27 12:00:00',
#                '2023-02-27 18:00:00', '2023-02-28 00:00:00'],
#               dtype='datetime64[ns]', length=217, freq='6h')

# %%
# M -> Month end
pd.date_range(start='2023/1/5',end='2023/2/28',freq='ME')
# Out:
# DatetimeIndex(['2023-01-31', '2023-02-28'], dtype='datetime64[ns]', freq='ME')

# %%
# MS -> Month start
pd.date_range(start='2023/1/26',end='2023/2/28',freq='MS')
# Out:
# DatetimeIndex(['2023-02-01'], dtype='datetime64[ns]', freq='MS')

# %%
# A -> Year end
pd.date_range(start='2023/1/5',end='2030/2/28',freq='YE')
# Out:
# DatetimeIndex(['2023-12-31', '2024-12-31', '2025-12-31', '2026-12-31',
#                '2027-12-31', '2028-12-31', '2029-12-31'],
#               dtype='datetime64[ns]', freq='YE-DEC')

# %%
# using periods(number of results)
pd.date_range(start='2023/1/5',periods=25,freq='M')
# Out:
# /tmp/ipykernel_2149/1478210292.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.date_range(start='2023/1/5',periods=25,freq='M')
# DatetimeIndex(['2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30',
#                '2023-05-31', '2023-06-30', '2023-07-31', '2023-08-31',
#                '2023-09-30', '2023-10-31', '2023-11-30', '2023-12-31',
#                '2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31',
#                '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31',
#                '2025-01-31'],
#               dtype='datetime64[ns]', freq='ME')

# %% [markdown]
# to_datetime function

# %%
# simple series example

s = pd.Series(['2023/1/1','2022/1/1','2021/1/1'])
pd.to_datetime(s).dt.day_name()
# Out:
# 0      Sunday
# 1    Saturday
# 2      Friday
# dtype: object

# %%
# simple series example

s = pd.Series(['2026/1/1','2025/1/1','2021/1/1'])
pd.to_datetime(s).dt.day_name()
# Out:
# 0     Thursday
# 1    Wednesday
# 2       Friday
# dtype: object

# %%
# with errors
s = pd.Series(['2023/1/1','2022/1/1','2021/130/1'])
pd.to_datetime(s,errors='coerce').dt.month_name()
# Out:
# 0    January
# 1    January
# 2        NaN
# dtype: object

# %%
df = pd.read_csv('/content/expense_data.csv')
df.shape
# Out:
# (277, 11)

# %%
df.head()
# Out:
#              Date               Account        Category  Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food          NaN
# 1  3/2/2022 10:11  CUB - online payment           Other          NaN
# 2  3/1/2022 19:50  CUB - online payment            Food          NaN
# 3  3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4  3/1/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
df.columns
# Out:
# Index(['Date', 'Account', 'Category', 'Subcategory', 'Note', 'INR',
#        'Income/Expense', 'Note.1', 'Amount', 'Currency', 'Account.1'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date                0
# Account             0
# Category            0
# Subcategory       277
# Note                4
# INR                 0
# Income/Expense      0
# Note.1            277
# Amount              0
# Currency            0
# Account.1           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 23.9+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 23.9+ KB

# %% [markdown]
# ### dt accessor
#
# Accessor object for datetimelike properties of the Series values.

# %%
df['Date'].dt.is_quarter_start
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 272    False
# 273    False
# 274    False
# 275    False
# 276    False
# Name: Date, Length: 277, dtype: bool

# %%
# plot graph
import matplotlib.pyplot as plt
plt.plot(df['Date'],df['INR'])

# %%
# day name wise bar chart/month wise bar chart

df['day_name'] = df['Date'].dt.day_name()

# %%
df.head()
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0
#
#     day_name
# 0  Wednesday
# 1  Wednesday
# 2    Tuesday
# ...

# %%
df.groupby('day_name')['INR'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='day_name'>

# %%
df['month_name'] = df['Date'].dt.month_name()

# %%
df.head()
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0
#
#     day_name month_name
# 0  Wednesday      March
# ...

# %%
df.groupby('month_name')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='month_name'>

# %%
df[df['Date'].dt.is_month_end]
# Out:
#                    Date               Account        Category  Subcategory  \
# 7   2022-02-28 11:56:00  CUB - online payment            Food          NaN
# 8   2022-02-28 11:45:00  CUB - online payment           Other          NaN
# 61  2022-01-31 08:44:00  CUB - online payment  Transportation          NaN
# 62  2022-01-31 08:27:00  CUB - online payment           Other          NaN
# 63  2022-01-31 08:26:00  CUB - online payment  Transportation          NaN
# 242 2021-11-30 14:24:00  CUB - online payment            Gift          NaN
# 243 2021-11-30 14:17:00  CUB - online payment            Food          NaN
# 244 2021-11-30 10:11:00  CUB - online payment            Food          NaN
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# 7                 Pizza  339.15        Expense     NaN  339.15      INR
# 8           From kumara  200.00         Income     NaN  200.00      INR
# 61           Vnr to apk   50.00        Expense     NaN   50.00      INR
# ...

# %%
df.groupby('Date')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>
